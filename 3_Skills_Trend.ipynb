# %% [markdown]
# ## How are in-demand skills trending for Data Analysts?
# ### Methology
# 1. Aggregate skill counts monthly
# 1. Re-analyze based on percentage of total jobs
# 1. Plot the monthly skill demand

# %%
import ast
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading Data
df = pd.read_csv('data_jobs.csv')

# %%
#Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA = df[df["job_title_short"] == "Data Analyst"].copy()
df_DA["month_num"] = df_DA["job_posted_date"].dt.month
df_DA_explode = df_DA.explode('job_skills')

# %%
df_pivot = df_DA_explode.pivot_table(index="month_num", columns="job_skills", aggfunc="size", fill_value=0)
df_pivot
# Out:
# job_skills  airflow  airtable  alteryx  angular  angular.js  ansible  apl  \
# month_num
# 1               197        17      551       63           2       20    2
# 2               169         2      448       49           0       14    1
# 3               181         4      442       34           0       23    6
# 4               155         4      413       22           0       11    8
# 5               128         8      310       30           0       19    9
# 6               164        14      393       29           0       14    9
# 7               207         4      366       15           0        8    5
# 8               197         3      413       21           0       12   10
# 9               118         4      317       21           0       14    3
# 10              173        11      350       40           0       19    0
# 11              169         7      293       24           0       19    0
# 12              144        10      274       28           0       13    0
#
# job_skills  arch  asana  asp.net  ...  webex  windows  wire  word  workfront  \
# month_num                         ...
# 1              1     29       34  ...     17      228     6  1778          0
# 2              4     27       13  ...      9      202     6  1235          4
# 3              1     17       13  ...      8      194     8  1203          1
# 4              9      9       15  ...      9      185    14  1177          8
# 5              2      8       21  ...     11      122     3   957          3
# 6              4     16       16  ...      8      157    14  1237          6
# 7              8     19       12  ...      5      161    11  1069          0
# 8              3     13       12  ...      9      184    11  1298          0
# 9             10     12       10  ...      4      150     8   945          0
# 10             8     11       14  ...      4      156     8   990          5
# 11             5      4       12  ...      4      144     4   887          1
# 12             8     11        9  ...      6      139     8   786          3
#
# job_skills  wrike  wsl  xamarin  yarn  zoom
# month_num
# 1              11    6        0     9    95
# 2               2    5        0     4    41
# 3               1    3        1     5    45
# 4               2    1        0     6    26
# 5               4    0        0     7    18
# 6               6    0        0    11    34
# 7               3    0        0     6    38
# 8               1    0        0    11    41
# 9               1    0        0     5    25
# 10              2    0        1     4    39
# 11              1    1        0     6    26
# 12              5    0        0     2    37
#
# [12 rows x 235 columns]

# %%
df_pivot = df_DA_explode.pivot_table(index="month_num", columns="job_skills", aggfunc="size", fill_value=0)
df_pivot.loc["total"] = df_pivot.sum()
df_pivot = df_pivot[df_pivot.loc["total"].sort_values(ascending=False).index]
df_pivot.drop("total", inplace=True)
df_pivot
# Out:
# job_skills    sql  excel  python  tableau  power bi     r   sas  powerpoint  \
# month_num
# 1           11336   8170    6606     5596      4285  3607  3830        1880
# 2            7947   5772    4751     3936      3307  2576  2634        1291
# 3            7868   5675    4741     4051      3176  2650  2554        1266
# 4            7553   5496    4557     3776      3106  2399  2598        1190
# 5            6617   4773    4070     3245      2695  2093  1940         979
# 6            7584   5724    4707     3812      3275  2442  2174        1173
# 7            7687   5513    4831     3928      3350  2444  2118        1096
# 8            8823   6482    5576     4533      3859  2975  2560        1332
# 9            6829   4886    4229     3446      3118  2146  1880         944
# 10           7474   5217    4693     3709      3340  2380  2114         955
# 11           6652   4776    4233     3284      3012  2159  1738         894
# 12           6058   4376    4196     3139      2857  2125  1858         822
#
# job_skills  word   sap  ...  xamarin  mattermost  gtx  esquisse  chainer  \
# month_num               ...
# 1           1778  1251  ...        0           0    0         0        0
# 2           1235   954  ...        0           0    0         0        0
# 3           1203   892  ...        1           0    0         0        0
# 4           1177   947  ...        0           0    0         0        0
# 5            957   851  ...        0           0    0         0        0
# 6           1237   987  ...        0           0    0         0        0
# 7           1069   996  ...        0           0    1         0        0
# 8           1298  1117  ...        0           0    0         0        0
# 9            945   852  ...        0           1    0         0        0
# 10           990   872  ...        1           0    0         0        0
# 11           887   808  ...        0           1    0         1        0
# 12           786   753  ...        0           0    0         0        1
#
# job_skills  capacitor  nuxt.js  msaccess  ovh  suse
# month_num
# 1                   1        1         0    0     0
# 2                   0        0         0    0     0
# 3                   0        0         0    0     1
# 4                   0        0         0    1     0
# 5                   0        0         1    0     0
# 6                   0        0         0    0     0
# 7                   0        0         0    0     0
# 8                   0        0         0    0     0
# 9                   0        0         0    0     0
# 10                  0        0         0    0     0
# 11                  0        0         0    0     0
# 12                  0        0         0    0     0
#
# [12 rows x 235 columns]

# %%
df_pivot.iloc[:, :5].plot(kind="line")
plt.title('Trending Top Skills for Data Analysts')
plt.ylabel('Count')
plt.xlabel('')
plt.show()

# %%
total_months = df_DA.groupby("month_num").size()
total_months
# Out:
# month_num
# 1     23585
# 2     16558
# 3     16243
# 4     15514
# 5     13423
# 6     16008
# 7     16095
# 8     18628
# 9     14969
# 10    16239
# 11    15230
# 12    13583
# dtype: int64

# %%
df_pivot = df_DA_explode.pivot_table(index="month_num", columns="job_skills", aggfunc="size", fill_value=0)
df_pivot.loc["total"] = df_pivot.sum()
df_pivot = df_pivot[df_pivot.loc["total"].sort_values(ascending=False).index]
df_pivot.drop("total", inplace=True)

# %%
df_pivot_percent = df_pivot.div(total_months / 100, axis=0)
df_pivot_percent["posted_month"] = df_pivot_percent.index.to_series().apply(lambda x: pd.to_datetime(x, format='%m').strftime('%b'))
df_pivot_percent.set_index("posted_month", inplace=True)
df_pivot_percent
# Out:
# job_skills          sql      excel     python    tableau   power bi  \
# posted_month
# Jan           48.064448  34.640661  28.009328  23.726945  18.168327
# Feb           47.994927  34.859283  28.693079  23.770987  19.972219
# Mar           48.439328  34.938127  29.187958  24.939974  19.553038
# Apr           48.685059  35.426067  29.373469  24.339306  20.020627
# May           49.295985  35.558370  30.321091  24.174924  20.077479
# Jun           47.376312  35.757121  29.404048  23.813093  20.458521
# Jul           47.760174  34.252874  30.015533  24.405095  20.813917
# Aug           47.364183  34.797080  29.933434  24.334335  20.716126
# Sep           45.620950  32.640791  28.251720  23.020910  20.829715
# Oct           46.025002  32.126362  28.899563  22.840076  20.567769
# Nov           43.676953  31.359160  27.793828  21.562705  19.776756
# Dec           44.599867  32.216742  30.891556  23.109770  21.033645
#
# job_skills            r        sas  powerpoint      word       sap  ...  \
# posted_month                                                        ...
# Jan           15.293619  16.239135    7.971168  7.538690  5.304219  ...
# Feb           15.557434  15.907718    7.796835  7.458630  5.761565  ...
# Mar           16.314720  15.723696    7.794127  7.406267  5.491596  ...
# Apr           15.463452  16.746165    7.670491  7.586696  6.104164  ...
# May           15.592639  14.452805    7.293452  7.129554  6.339864  ...
# Jun           15.254873  13.580710    7.327586  7.727386  6.165667  ...
# Jul           15.184840  13.159366    6.809568  6.641814  6.188257  ...
# Aug           15.970582  13.742753    7.150526  6.968005  5.996350  ...
# Sep           14.336295  12.559289    6.306366  6.313047  5.691763  ...
# Oct           14.656075  13.018043    5.880904  6.096435  5.369789  ...
# Nov           14.175968  11.411687    5.869993  5.824032  5.305318  ...
# Dec           15.644556  13.678863    6.051682  5.786645  5.543694  ...
#
# job_skills     xamarin  mattermost       gtx  esquisse   chainer  capacitor  \
# posted_month
# Jan           0.000000    0.000000  0.000000  0.000000  0.000000    0.00424
# Feb           0.000000    0.000000  0.000000  0.000000  0.000000    0.00000
# Mar           0.006156    0.000000  0.000000  0.000000  0.000000    0.00000
# Apr           0.000000    0.000000  0.000000  0.000000  0.000000    0.00000
# May           0.000000    0.000000  0.000000  0.000000  0.000000    0.00000
# Jun           0.000000    0.000000  0.000000  0.000000  0.000000    0.00000
# Jul           0.000000    0.000000  0.006213  0.000000  0.000000    0.00000
# Aug           0.000000    0.000000  0.000000  0.000000  0.000000    0.00000
# Sep           0.000000    0.006680  0.000000  0.000000  0.000000    0.00000
# Oct           0.006158    0.000000  0.000000  0.000000  0.000000    0.00000
# Nov           0.000000    0.006566  0.000000  0.006566  0.000000    0.00000
# Dec           0.000000    0.000000  0.000000  0.000000  0.007362    0.00000
#
# job_skills    nuxt.js  msaccess       ovh      suse
# posted_month
# Jan           0.00424   0.00000  0.000000  0.000000
# Feb           0.00000   0.00000  0.000000  0.000000
# Mar           0.00000   0.00000  0.000000  0.006156
# Apr           0.00000   0.00000  0.006446  0.000000
# May           0.00000   0.00745  0.000000  0.000000
# Jun           0.00000   0.00000  0.000000  0.000000
# Jul           0.00000   0.00000  0.000000  0.000000
# Aug           0.00000   0.00000  0.000000  0.000000
# Sep           0.00000   0.00000  0.000000  0.000000
# Oct           0.00000   0.00000  0.000000  0.000000
# Nov           0.00000   0.00000  0.000000  0.000000
# Dec           0.00000   0.00000  0.000000  0.000000
#
# [12 rows x 235 columns]

# %%
from matplotlib.ticker import PercentFormatter

df_plot = df_pivot_percent.iloc[:,:5]
sns.set_theme(style="ticks")
sns.lineplot(data=df_plot, legend=False, dashes=False)

plt.title('Trending Top Skills for Data Analysts')
plt.ylabel('Likelihood in Job Posting')
plt.xlabel('2023')
sns.despine()

plt.gca().yaxis.set_major_formatter(PercentFormatter(decimals=0))
for i in range(5):
    plt.text(11.2, df_plot.iloc[-1, i], df_plot.columns[i])

plt.show()
